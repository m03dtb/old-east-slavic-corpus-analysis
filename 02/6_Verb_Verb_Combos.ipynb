# %% [markdown]
# # File 02/6 – Verb-Verb-Combos

# %% [markdown]
# ### DESCRIPTION:
# For each sentence in the DataFrame:
# - The main verb of a compound tense construction is identified and marked in   column `Is_Compound_Main`.
# - Auxiliary verbs are assigned to their main verb via `Compound_Aux_Forms` and `Compound_Aux_IDs`
#   (token IDs of the auxiliary verbs).
# - Auxiliary verbs participating in compound tense constructions are marked in `Is_Compound_Aux`.
#
# #### INPUT FILES:
# - ./OUTPUST/dataframe_02_5.csv
# #### OUTPUT FILES:
# - ./OUTPUTS/dataframe_02_6.csv

# %% [markdown]
# ## Imports

# %%
# third-party imports
import pandas as pd

# %% [markdown]
# ## Read input file and print columns

# %%
csv_path="OUTPUTS/dataframe_02_5.csv"

df = pd.read_csv(
    csv_path,
    dtype={
        "Russian Translation": "string",
        "English Translation": "string"
    }
)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'File', 'Text Title', 'Language', 'Sentence ID',
#        'Token ID', 'Form', 'Lemma', 'Lemma_norm', 'V_yva', 'V_nuti', 'V_COMB',
#        'V_prefix', 'POS', 'Morphology', 'Head ID', 'Relation',
#        'Presentation After', 'Russian Translation', 'English Translation',
#        'Type', 'century', 'exact', 'lang', 'region', 'Negation',
#        'Negation_Marker', 'place', 'Sentence_Text'],
#       dtype='object')

# %% [markdown]
# ## A. Compound verb detection and analysis
# ### - Identify auxiliary chains (recursive)
# - helper function called by fn mark_compound_verbs()

# %%
def collect_aux_chain(start_id, group, AUX_LEMMAS):
    """ 
    Collect all auxiliary tokens linked to a given head token (typically a verb)
    via dependency relation 'aux', including recursively chained auxiliaries.

    Args:
        start_id (int):
            Token ID of the head (e.g. main verb) from which to start traversal.
        group (pd.DataFrame):
            Subset of the DataFrame representing a single sentence.
            Must contain at least:
            'Token ID', 'Head ID', 'Lemma','Form','Relation','Morphology','Negation'
        AUX_LEMMAS (set[str]):
            Set of lemmas considered auxiliary verbs.

    Returns:
        Tuple[List, List, List, List, List]:
            - forms:  list of surface forms of auxiliary tokens
            - ids:    list of Token IDs of auxiliaries
            - lemmas: list of lemmas of auxiliaries
            - morphs: list of morphology annotations
            - negs:   list of negation flags for each auxiliary

    Notes:
        - Traversal is recursive (DFS) to capture chains of auxiliaries.
        - Each auxiliary is visited only once (cycle-safe via `visited` set).
        - Only tokens with relation 'aux' and lemma in AUX_LEMMAS are included.

    Example:
        start_id = 2157784
        -> returns auxiliaries attached to this verb (e.g. 'быти', negation particles, etc.)
    """
    forms, ids, lemmas, morphs, negs = [], [], [], [], []
    visited = set()

    def dfs(head_id):
        for _, r in group.iterrows():
            if (
                pd.notna(r['Head ID']) and
                int(r['Head ID']) == head_id and
                r['Lemma'] in AUX_LEMMAS and
                r['Relation'] == 'aux'
            ):
                aid = int(r['Token ID'])
                if aid in visited:
                    continue
                visited.add(aid)

                forms.append(r['Form'])
                ids.append(aid)
                lemmas.append(r['Lemma'])
                morphs.append(r['Morphology'])
                negs.append(r["Negation"])

                dfs(aid)

    dfs(start_id)
    return forms, ids, lemmas, morphs, negs

# %% [markdown]
# ### - Detect and annotate compound verbs
# - calls fn: collect_aux_chains()

# %%
def mark_compound_verbs(df: pd.DataFrame, AUX_LEMMAS=None) -> pd.DataFrame:
    """
    For every sentence: mark those main verbs with an auxiliary verb (aux) 'byti'. 
    Add the following three new cols to the DataFrame to the MAIN VERB: 
    
      - 'Is_Compound_Main'    
          (True, if this token is the main verb as part of a compound verb)
          
      - 'Compound_Aux_Forms'  
          (List of all auxiliary forms of 'быти' that belong to the compound verb)
          
      - 'Compound_Aux_IDs'    
          (List of all Token-IDs of the auxiliaries of 'быти' found for the main verb)
    """
    if AUX_LEMMAS is None:
        AUX_LEMMAS = {"быти"}   # default

    df = df.copy()
    
    # Initialise new columns 
    ## with default boolean False  
    for col in ["Is_Compound_Main", "Is_Compound_Aux"]:
        df[col] = False

    ## with list columns (each row gets its own list)    
    for col in [
        "Compound_Aux_Forms",
        "Compound_Aux_IDs",
        "Compound_Aux_Lemmas",
        "Compound_Aux_Morphology",
        "Compound_Aux_Negation"
    ]:
        df[col] = [[] for _ in range(len(df))]

    # group after sentence id -> so that the search will be done inside of the 
    # separate sentences 
    for sid, group in df.groupby('Sentence ID'):
        # 1) find all auxiliaries 'byti' (defined by properties: relation == "aux"; 
        # Lemma == 'быти' ('byti'), POS = "V-" )
        aux_byti = group.loc[
            (group['Lemma'].isin(AUX_LEMMAS)) &
            (group['Relation'] == 'aux'),
            # For each entry: create a PANDAS DF containing the columns 'Token ID',
            # 'Form' and 'Head ID'
            ['Token ID', 'Form', 'Lemma',  'Morphology','Head ID']
        ]

        # mark auxiliary verbs of 'byti' in the DataFrame:
        # iterate over the Token IDs in the auxiliary DataFrame (aux_byti),
        # locate the corresponding rows in the main DataFrame (df),
        # and set 'Is_Compound_Aux' to True for those tokens
        for aux_tid in aux_byti['Token ID']:
            df.loc[df['Token ID'] == aux_tid, 'Is_Compound_Aux'] = True

        # 2) build two maps:
        # aux_map_forms:  main_verb_id -> list of auxiliary forms
        aux_map_forms = {}
        # aux_map_ids:    main_verb_id -> list of auxiliary verbs' token IDs
        aux_map_ids   = {}
        # aux_map_lemmas: lemma form of aux_map_forms
        aux_map_lemmas = {}
        # aux_map_morph:  morphology of aux_map_forms
        aux_map_morph = {}
        
        for _, row in aux_byti.iterrows():
            main_id      = int(row['Head ID'])    # the auxiliary verb's ID
            form_aux     = row['Form']            # e.g. 'ѥсмь' ("jesm'")
            lemma_aux    = row['Lemma']
            aux_token_id = int(row['Token ID'])   # e.g. 2157785
            morph_aux = row['Morphology']

            aux_map_forms.setdefault(main_id, []).append(form_aux)
            aux_map_lemmas.setdefault(main_id, []).append(lemma_aux)
            aux_map_ids.setdefault(main_id, []).append(aux_token_id)
            aux_map_morph.setdefault(main_id, []).append(morph_aux)


        # 3) mark the main verbs in aux_map_forms.keys()
        # 3) mark main verbs using recursive aux collection
        for _, row in group.iterrows():
            tid = int(row['Token ID'])
        
            #forms, ids, lemmas, morphs = collect_aux_chain(tid)
            forms, ids, lemmas, morphs, negs = collect_aux_chain(tid, group, AUX_LEMMAS)
        
            if forms:
                df.at[row.name, 'Is_Compound_Main'] = True
                df.at[row.name, 'Compound_Aux_Forms'] = forms
                df.at[row.name, 'Compound_Aux_IDs'] = ids
                df.at[row.name, 'Compound_Aux_Lemmas'] = lemmas
                df.at[row.name, 'Compound_Aux_Morphology'] = morphs
                df.at[row.name, "Compound_Aux_Negation"] = negs
                
    return df


# function call: 
#AUX_LEMMAS = {"быти", "имѣти"}
AUX_LEMMAS = {"быти"}
df = mark_compound_verbs(
    df,
    AUX_LEMMAS
)

# %% [markdown]
# ### Query: verbs with X auxiliaries

# %%
def show_main_verbs_with_X_auxiliaries(auxiliary_count=1) -> pd.DataFrame:
    """
    Return all verbs that are marked as compound main verbs and have
    exactly `auxiliary_count` auxiliary forms.
    """
    df_sub = df.loc[
        (df['Is_Compound_Main']) &
        (df['Compound_Aux_Forms'].apply(len) == auxiliary_count),
        [
            "Form", "Sentence_Text",
            "Is_Compound_Main", "Is_Compound_Aux",
            "Compound_Aux_Forms", "Compound_Aux_IDs",
            "Compound_Aux_Lemmas", "Compound_Aux_Morphology", 
            "Compound_Aux_Negation"
        ]
    ]

    return df_sub

# %%
# Examples: verbs with 1–3 auxiliaries
from IPython.display import display, Markdown

for n in range(1, 4):
    display(Markdown(f"### num of aux verbs: {n}"))
    display(show_main_verbs_with_X_auxiliaries(n).head(2))
# Out:
# ### num of aux verbs: 1
#          Form                                   Sentence_Text  \
# 11   повелѣлъ  азъ ѥсмь повелѣлъ ѿдати бѹицѣ (и (съ, съ, съ))
# 116      далъ               ꙗ ѥсмь далъ блюдо (серебрьно, въ)
#
#      Is_Compound_Main  Is_Compound_Aux Compound_Aux_Forms Compound_Aux_IDs  \
# 11               True            False             [ѥсмь]        [2157785]
# 116              True            False             [ѥсмь]        [2157889]
#
#     Compound_Aux_Lemmas Compound_Aux_Morphology Compound_Aux_Negation
# 11               [быти]            [1spia----i]               [False]
# 116              [быти]            [1spia----i]               [False]
# ### num of aux verbs: 2
#           Form                        Sentence_Text  Is_Compound_Main  \
# 3266  изволили  вы бы есте изволили воли (две, мои)              True
# 3280     сняли       бы есте сняли колокол (вечной)              True
#
#       Is_Compound_Aux Compound_Aux_Forms    Compound_Aux_IDs  \
# ...

# %% [markdown]
# ## Statistics
# ### Verb distribution by number of auxiliaries
# - count of verbs grouped by number of auxiliary elements

# %%
df["Compound_Aux_Lemmas"].apply(len).value_counts()
# Out:
# Compound_Aux_Lemmas
# 0    234166
# 1      1091
# 2        18
# Name: count, dtype: int64

# %% [markdown]
# ### List of existing columns in the data frame

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'File', 'Text Title', 'Language', 'Sentence ID',
#        'Token ID', 'Form', 'Lemma', 'Lemma_norm', 'V_yva', 'V_nuti', 'V_COMB',
#        'V_prefix', 'POS', 'Morphology', 'Head ID', 'Relation',
#        'Presentation After', 'Russian Translation', 'English Translation',
#        'Type', 'century', 'exact', 'lang', 'region', 'Negation',
#        'Negation_Marker', 'place', 'Sentence_Text', 'Is_Compound_Main',
#        'Is_Compound_Aux', 'Compound_Aux_Forms', 'Compound_Aux_IDs',
#        'Compound_Aux_Lemmas', 'Compound_Aux_Morphology',
#        'Compound_Aux_Negation'],
#       dtype='object')

# %% [markdown]
# ## Validate compound auxiliary structure

# %% [markdown]
# ### I. Validate compound auxiliary columns (main verbs)
# - ensure compound main verbs (`Is_Compound_Main == True`) have:
#   - non-empty auxiliary IDs and forms
# - verify one-to-one alignment between auxiliary IDs and forms

# %%
assert (
    df.loc[df["Is_Compound_Main"], "Compound_Aux_IDs"]
      .apply(lambda ids: len(ids) > 0)
      .all()
), "Some compound main verbs have no auxiliary IDs"

# %%
assert (
    df.loc[df["Is_Compound_Main"], "Compound_Aux_Forms"]
      .apply(lambda ids: len(ids) > 0)
      .all()
), "Some compound main verbs have no auxiliary forms"

# %%
# get an indexed series (True/False) for condition:
# list in col "Compound_Aux_IDs" is not empty
mask_has_aux = df["Compound_Aux_IDs"].apply(lambda ids: len(ids) > 0)

# assert for these entries: 
# elements in List of col "Compound_Aux_IDs" and col "Compound_Aux_Forms"
# have the same length 
assert (
    df.loc[mask_has_aux, ["Compound_Aux_IDs", "Compound_Aux_Forms"]]
      .apply(lambda row: len(row["Compound_Aux_IDs"]) == len(row["Compound_Aux_Forms"]), axis=1)
      .all()
), "Mismatch between number of auxiliary IDs and forms"

# %%
display(df.loc[mask_has_aux].head(3))
mask_has_aux.value_counts()
# Out:
#      Unnamed: 0 File         Text Title Language  Sentence ID  Token ID  \
# 11           11  mst  Mstislav’s letter      orv       189407   2157784
# 116         116  mst  Mstislav’s letter      orv       189417   2157888
# 127         127  mst  Mstislav’s letter      orv       189702   2157899
#
#          Form     Lemma Lemma_norm  V_yva  ...  Negation_Marker     place  \
# 11   повелѣлъ  повелѣти   повелети  False  ...              NaN  Novgorod
# 116      далъ      дати       дати  False  ...              NaN  Novgorod
# 127    велѣлъ    велѣти     велети  False  ...              NaN  Novgorod
#
#                                       Sentence_Text Is_Compound_Main  \
# 11   азъ ѥсмь повелѣлъ ѿдати бѹицѣ (и (съ, съ, съ))             True
# 116               ꙗ ѥсмь далъ блюдо (серебрьно, въ)             True
# 127                                ѥсмь велѣлъ бити             True
#
#     Is_Compound_Aux  Compound_Aux_Forms Compound_Aux_IDs Compound_Aux_Lemmas  \
# ...

# %% [markdown]
# ### II. Validate auxiliary entries (non-main)
#
#
# For rows where `Is_Compound_Aux == True`:
# - the following columns should contain **empty lists**:
#   - `Compound_Aux_Forms`
#   - `Compound_Aux_IDs`
#   - `Compound_Aux_Lemmas`
#   - `Compound_Aux_Morphology`
#   - `Compound_Aux_Negation`
#
# Reason:
# - these rows represent auxiliary verbs themselves, not main verbs
# - therefore, they do not govern further auxiliary chains
# - auxiliary chains are only stored for the corresponding main verb

# %%
df[df["Is_Compound_Aux"] == True].head(2)
# Out:
#      Unnamed: 0 File         Text Title Language  Sentence ID  Token ID  Form  \
# 12           12  mst  Mstislav’s letter      orv       189407   2157785  ѥсмь
# 117         117  mst  Mstislav’s letter      orv       189417   2157889  ѥсмь
#
#     Lemma Lemma_norm  V_yva  ...  Negation_Marker     place  Sentence_Text  \
# 12   быти       быти  False  ...              NaN  Novgorod           ѥсмь
# 117  быти       быти  False  ...              NaN  Novgorod           ѥсмь
#
#     Is_Compound_Main Is_Compound_Aux  Compound_Aux_Forms Compound_Aux_IDs  \
# 12             False            True                  []               []
# 117            False            True                  []               []
#
#     Compound_Aux_Lemmas Compound_Aux_Morphology Compound_Aux_Negation
# 12                   []                      []                    []
# 117                  []                      []                    []
#
# [2 rows x 36 columns]

# %% [markdown]
# ### Write pandas DataFrame to csv

# %%
df.to_csv("./OUTPUTS/dataframe_02_6.csv")
