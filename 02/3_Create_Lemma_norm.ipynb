# %% [markdown]
# # File 02/3 – Create Lemma_norm

# %% [markdown]
# ### DESCRIPTION:
# - Creates a new column "Lemma_norm". This column contains a graphematically simplified string based on the column "Lemma".
#
# #### Background:
# - Graphematic realizations differ in Old East Slavonic.
# - Thus, for example, the realization of soft signs changed over time and was often not applied uniformly.
# - In addition, the same letters may have multiple graphematic variants. This script aims to normalize such graphematic variation.
# - Homonym indexing added by the editors is removed as part of the normalization process.
#
# #### INPUT FILES:
#  - "./OUTPUTS/dataframe_02_2.csv"
#
# #### OUTPUT FILES:
#  - "./OUTPUTS/dataframe_02_3.csv"

# %% [markdown]
# ## Environment setup

# %%
# enable automatic reloading of imported modules
# %load_ext autoreload
# %autoreload 2
    
# custom utility: extract metadata containing info like columns, amount of files, etc.
from utils.metadata import get_meta_data
from utils.uniq_files import get_uniq_files

# %% [markdown]
# ## Imports

# %%
# standard library imports
import re
# third-party imports
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Read input file

# %%
# read the input file 
df = pd.read_csv(
    "./OUTPUTS/dataframe_02_2.csv",
    low_memory=False,
)

# %% [markdown]
# ## Delete columns "Unnamed"

# %%
def drop_unnamed_columns(df):
    """
    Drop columns whose names start with 'Unnamed', typically created
    when saving/loading DataFrames with an index in CSV format.
    """
    return df.loc[:, ~df.columns.str.startswith("Unnamed")]

df = drop_unnamed_columns(df)

# %% [markdown]
# ## Dataset summary

# %%
# utils.metadata -> get overview of most important data 
df = get_meta_data(df)

# %%
# utils import
language_by_file = get_uniq_files(df,print_me=True)

# %% [markdown]
# ## Extract a set of all verbs in "Lemma"

# %%
def get_list_of_base_form_verbs(df, column):
    """
    Extract sorted list of unique verb base forms from a given column.

    - Filters rows where POS == "V-"
    - Selects values from the specified column (e.g. "Lemma")
    - Returns a sorted list of unique entries
    """

    # filter verb rows
    mask = df["POS"] == "V-"

    # extract base forms
    base_forms = df.loc[mask, column]

    # return sorted unique values
    return sorted(base_forms.dropna().unique())

# create list by function call
base_forms_list = get_list_of_base_form_verbs(df, "Lemma")

# %%
# show list for overview
print(len(base_forms_list), "\n")
print("first 20:", base_forms_list[:20], "\n")
print("last 20:", base_forms_list[-20:])

# %% [markdown]
# ## Create CSV containing all lemmas
# output file name: "BASE_FORM_LIST.CSV"

# %%
def create_base_form_list(base_form_list):
    """
    Write a list of base forms (strings) to a CSV file (one entry per line).
    """
    with open(base_form_list, "w", encoding="utf-8") as f:
        for word in base_forms_list:
            f.write(word + "\n")

# function call 
create_base_form_list("base_form_list.csv")

# %% [markdown]
# ## Extract character set from verb lemmas

# %%
def get_all_letters_used_for_verbs(base_forms_list):
    """ 
    Extract all variants of letters used in the verbs 
    """
    return {char for word in base_forms_list for char in word}

# function call 
all_letters = get_all_letters_used_for_verbs(base_forms_list)

print("Used letters in verbs:", sorted(all_letters))
print("Amount of unique letters:", len(all_letters))

# %% [markdown]
# ## Normalize verb lemmas (Lemma → Lemma_norm)
#
# - derive normalized forms from column `Lemma`
# - map graphemes to a simplified form
# - store result in `Lemma_norm`
#
# > **Note:** the normalization scheme is based on characters observed in verb lemmas, but is applied to all tokens. If other word classes are to be analyzed, the normalization should be adapted using a character set derived from the full dataset.

# %%
df = df.copy()

# 1. One single placeholder char for both JER variants, i.e. <ь> and <ъ>
JER = "_" 

# 2. Digraphs to be replaced before replacing single graphemes
DIGRAPHS = {
    "оу": "у",
    "ѹ": "у",
}

# 3. Mapping table
CHAR_MAP = {
    "#": "", " ": "", "1": "", "2": "", "?": "_",
    "ѣ": "е", "ҍ":"е","ѥ": "е",
    "ѧ": "я", "ѩ": "я", "ꙗ": "я",
    "ꙑ": "ы",
    "ѫ": "у","s":"з","ѕ":"з",
    # JER replacement
    "ъ": JER, "ь": JER,
}


def normalize_letters(text):
    """
     Normalize graphemes to a reduced character set.

    - Replaces digraphs (e.g. "оу", "ѹ") with single characters
    - Maps variant graphemes to canonical forms (e.g. "ѣ" → "е")
    - Replaces JER characters ("ъ", "ь") with a unified placeholder
    - Removes unwanted symbols (e.g. digits, spaces)
    """
    if not isinstance(text, str):
        return text

    # a) replace DIGRAPHS 
    for old, new in DIGRAPHS.items():
        text = text.replace(old, new)

    # b) all other letters where one letter corresponds to 
    # one single other letter 
    text = text.translate(str.maketrans(CHAR_MAP))
    
    return text

# function call 
# 1. create new column 'Lemma_norm'
df.loc[:, 'Lemma_norm'] = df['Lemma'].apply(normalize_letters)

# 2. insert 'Lemma_norm' to the right of 'Lemma' 
pos = df.columns.get_loc("Lemma")
norm = df.pop("Lemma_norm")
df.insert(pos+1, "Lemma_norm", norm)

# %%
df.columns

# %% [markdown]
# ## Validate lemma normalization
# - ensure `Lemma_norm` column exists
# - verify identical NaN positions in `Lemma` and `Lemma_norm`
# - ensure all non-missing lemmas were normalized

# %%
# ensure that the normalized column was successfully created
assert "Lemma_norm" in df.columns, \
    "Column 'Lemma_norm' does not exist in DataFrame"

# verify that missing values (NaN) occur at the same positions
# in both 'Lemma' and 'Lemma_norm' (no unintended loss or creation of NaNs)
assert df["Lemma"].isna().equals(df["Lemma_norm"].isna()), \
    "Mismatch in NaN positions between 'Lemma' and 'Lemma_norm'"

# ensure that every non-missing lemma has a corresponding normalized value
mask = df["Lemma"].notna()
assert df.loc[mask, "Lemma_norm"].notna().all(), \
    "Some non-NaN lemmas were not normalized"

# %% [markdown]
# ## Verify normalization results
#
# - inspect sample mappings (`Lemma` → `Lemma_norm`)
# - review resulting verb base forms
# - compare character sets before and after normalization

# %%
# inspect sample rows to visually verify Lemma -> Lemma_norm mapping
df.loc[:, ["Lemma", "Lemma_norm"]].head()

# %%
# get the forms in "Lemma_norm"
input_col = "Lemma_norm"
base_forms_list_new = get_list_of_base_form_verbs(df, input_col)

print(len(base_forms_list_new))
print(base_forms_list_new[:20], "\n")

# print list of all unique letters in "Lemma_norm"
# in order to see if any unintended letters remain
all_letters_in_verbs_set_new = get_all_letters_used_for_verbs(base_forms_list_new)

# %%
# Show which graphemes were eliminated / replaced by other graphemes 
all_letters.difference(all_letters_in_verbs_set_new)

# %%
df

# %% [markdown]
# ## Write data frame to CSV

# %%
df.to_csv("OUTPUTS/dataframe_02_3.csv")
