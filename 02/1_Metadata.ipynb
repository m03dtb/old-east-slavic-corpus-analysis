# %% [markdown]
# # FILE 02/1 – Metadata

# %% [markdown]
# ### DESCRIPTION:
# - extracts metadata fields ["century", "exact", "lang", "source", "place] from YAML
# - validates bidirectional consistency between YAML and DataFrame (files and texts)
# - enriches the DataFrame with the extracted metadata columns
#
# #### INPUT FILES:
# -  ../01/OUTPUTS/dataframe_01_02.csv
# -  ./metadata/metadata.yaml
#
# #### OUTPUT FILES:
# - ./OUTPUTS/dataframe_02_1.csv

# %% [markdown]
# ## Imports

# %%
# standard library imports
import os
import re
import shutil

# third-party imports
import pandas as pd
import yaml

# %% [markdown]
# ## Define input and output file paths

# %%
# file and dir const paths
## input
INPUT_FILE="../01/OUTPUTS/dataframe_01_02.csv"
YAML_FILE="./metadata/metadata.yaml"
## output
OUTPUT_DIR = "./OUTPUTS"

# %% [markdown]
# ## Output Directory
# Delete old output files created with this script

# %%
if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR)

# create new OUTPUT_DIR
os.makedirs(OUTPUT_DIR)

# %% [markdown]
# ## Read DataFrame

# %%
# read in the csv file as data frame 
# convert translation columns to strings 
df = pd.read_csv(
    INPUT_FILE,              
    dtype = {
        "Russian Translation": "string",
        "English Translation": "string"
    }
)

# convert df["Head ID"] entries to numeric values 
df['Head ID'] = (
    pd.to_numeric(
        df['Head ID'],
        errors='coerce'
    )
    .astype('Int64')
)

# %% [markdown]
# ## Filter language
# filter the data for the language you want to analyse (here: Old East Slavic, i.e. "OR" ("Old Russian") is kept,  all other language types (i.e. (Old) Church Slavonic)) are dropped

# %%
# filter the data frame for the language(s) you want to analyse (here: OR, i.e. Old Russian (synonym: Old East Slavic))
types_to_keep = ['OR']

# data frame with filtered files 
df = df[df['Type'].isin(types_to_keep)]

# %% [markdown]
# ## Check if filter worked

# %%
def ensure_unwanted_files_deleted(df, files_to_remove):
    """
    Ensure that unwanted files are not present in the DataFrame.
    Raises a detailed AssertionError if any are found.
    """

    # 1. Column exists?
    assert 'File' in df.columns, "Column 'File' not found in DataFrame"

    # 2. Find unwanted rows
    mask = df['File'].isin(files_to_remove)

    if mask.any():
        remaining = df.loc[mask, 'File'].unique()

        raise AssertionError(
            f"Unwanted files still present: {list(remaining)}"
        )

# function args and function call
# here the list contains (O)CS texts; adjust the list, if necessary.
files_to_remove = ['supr', 'zogr', 'kiev-mis', 'vit-const', 'vit-meth', 'psal-sin']
ensure_unwanted_files_deleted(df, files_to_remove)

# %%
df_filtered = df["File"].unique() # set of files remaining
print(df_filtered)
# Out:
# ['mst' 'mstislav-col' 'birchbark' 'pskov' 'const' 'luk-koloc' 'lav'
#  'smol-pol-lit' 'nov-sin' 'avv' 'kiev-hyp' 'peter' 'vest-kur' 'spi'
#  'zadon' 'rusprav' 'pskov-ivan' 'rig-smol1281' 'drac' 'sergrad' 'nov-list'
#  'ostromir-col' 'varlaam' 'afnik' 'dux-grjaz' 'ust-vlad' 'riga-goth'
#  'domo' 'usp-sbor' 'schism' 'nov-marg' 'suz-lav' 'novgorod-jaroslav'
#  'pvl-hyp']

# %% [markdown]
# ## Validation of DataFrame Titles against YAML Metadata
#
# This section validates the consistency between text titles in the DataFrame and
# the expected titles defined in the YAML metadata.
#
# For each file, titles are classified into:
# - titles present in the DataFrame but not defined in YAML ("only_in_df")
# - titles defined in YAML but missing in the DataFrame ("only_in_yaml")
# - titles matching between both sources ("in_both")
#
# Matching supports exact matches as well as wildcard-based patterns defined in the YAML.

# %%
def parse_yaml_titles(yaml_entries):
    """
    Parse YAML title entries into matching categories.

    The function extracts three components:
    - a global wildcard flag ("*")
    - a set of exact titles
    - a set of prefix patterns (for entries ending with " *")

    Args:
        yaml_entries (list): List of YAML entries (strings or dictionaries)
            containing title information.

    Returns:
        Tuple[bool, Set[str], Set[str]]:
            - wildcard_global (bool): True if global wildcard "*" is present
            - exact_titles (Set[str]): Titles requiring exact match
            - prefix_titles (Set[str]): Prefixes for wildcard matching
    """
    wildcard_global = False
    exact_titles = set()
    prefix_titles = set()

    for entry in yaml_entries:
        # normalize and classify title entry
        if isinstance(entry, str):
            title = entry
        elif isinstance(entry, dict):
            title = entry.get("title") or entry.get("text")
        else:
            continue

        if not isinstance(title, str):
            continue

        title = title.strip()

        # global wildcard flag ("*")
        # is used for "title" if there are no titles in the file 
        # which can or shall be differentiated.  
        # YAML data are for entry of file X apply to all cols "file"=="X"
        # in the data frame 
        if title == "*":
            wildcard_global = True
        # set of prefix patterns (for entries ending with " *")    
        elif title.endswith(" *"):
            prefix_titles.add(title[:-2])
        else:
            # ex
            exact_titles.add(title)

    return wildcard_global, exact_titles, prefix_titles

# %%
def compare_titles(df, yaml_path):
    """
    Compare DataFrame text titles with YAML metadata titles using exact and wildcard matching.

    YAML semantics:
    - "*"            -> global wildcard (all DataFrame titles are accepted)
    - "<prefix> *"   -> prefix wildcard (matches titles starting with <prefix>)
    - otherwise      -> exact title match

    Args:
        df (pd.DataFrame): DataFrame containing at least the columns "File" and "Text Title".
        yaml_path (str): Path to YAML file containing title metadata.

    Returns:
        dict:
            Mapping from file identifier to comparison results:
            {
                file: {
                    "only_in_df": Set[str],
                    "only_in_yaml": Set[str],
                    "in_both": Set[str]
                }
            }
    """
    # open YAML file and store content
    with open(yaml_path, "r", encoding="utf-8") as f:
        meta_info = yaml.safe_load(f)

    result = {}

    # iterate over set of values in column "File" of the data frame 
    for file in df["File"].unique():
        # get the set of titles for the file if title exists
        # removes None or NaN
        # INFO: set is needed for later operations
        df_titles = set(
            df.loc[df["File"] == file, "Text Title"].dropna().unique()
        )
    
        yaml_entries = meta_info.get(file, [])

        # call fn parse_yaml_titles() to receive the file's 
        # wildcards, exact and prefixed titles
        wildcard_global, exact_titles, prefix_titles = parse_yaml_titles(yaml_entries)

        # if global wildcard in the YAML 
        if wildcard_global:
            result[file] = {
                # no differences: all titles are accepted due to global wildcard "*" 
                "only_in_df": set(),
                "only_in_yaml": set(),
                # all DataFrame titles are considered valid matches
                "in_both": df_titles,
            }
            # skip further matching logic for this file (all titles already accepted)
            continue

        # identify DataFrame titles that match YAML entries
        # match if:
        # - exact match with YAML title
        # - or prefix match ("<prefix> *" pattern)
        matched_df_titles = {
            t for t in df_titles
            if t in exact_titles 
            # allow prefix matching: YAML may define shortened titles 
            # (e.g. "Life of Alexander")
            # which match full titles in the DataFrame 
            # (e.g. "Life of Alexander the Great")
            or any(t.startswith(p) for p in prefix_titles)
        }

        # classify titles into differences and matches
        result[file] = {
            # titles present in DataFrame but not matched by YAML
            "only_in_df": df_titles - matched_df_titles,
            # titles defined in YAML but not found in DataFrame
            "only_in_yaml": exact_titles - matched_df_titles,
            # titles matching between DataFrame and YAML
            "in_both": matched_df_titles,
        }

    return result

# function call
comparison = compare_titles(df, YAML_FILE)

mismatches = {}

# collect files with mismatches between DataFrame and YAML
for file, comp in comparison.items():
    if comp["only_in_df"] or comp["only_in_yaml"]:
        mismatches[file] = comp

# %% [markdown]
# ## Inspect mismatches between DataFrame and YAML
#
# - lists texts that appear:
#   - only in the DataFrame
#   - only in the YAML metadata
# - grouped by file
#
# **Aim**: ensure alignment between processed data and metadata sources

# %%
# prints existing mismatches
for file, diff in mismatches.items():
    print(f"________ FILE: {file} ________\n")

    if diff["only_in_df"]:
        print("ONLY IN DF:")
        print(diff["only_in_df"])

    if diff["only_in_yaml"]:
        print("ONLY IN YAML:")
        print(diff["only_in_yaml"])
    print("\n")

# %% [markdown]
# ## Join DataFrame and YAML-File:

# %%
def enrich_with_wildcard(df_in, yaml_path, yaml_cols):
    """
    - Extract"century","exact","lang","source","place" aus der YAML
      for each "Text" (e.g. afnik) and the titles "Title"
    - Use wildcard '*' in YAML, which leads to inheriting "Title" 
    - Use Wildcard 'Any Text *' in YAML, if 'Any Text 1', 'Any Text 2' etc.
      (relevant e.g. if 'Any Text' was created the same year and was written by the same author (or missing infos)) 
    """
    # open and read from YAML file 
    with open(yaml_path, "r", encoding="utf-8") as f:
        meta_info = yaml.safe_load(f)

    # columns to be added
    
    # copy df, initialize empty df columns to store the metadata 
    # stored in the YAML file 
    df = df_in.copy()
    for col in yaml_cols:
        df[col] = None

    # iterate over the keys "file_key" of the meta_info
    for file_key, entries in meta_info.items():
        # mask_file stores boolean 
        mask_file = df["File"] == file_key

        for e in entries:
            # get either text or title 
            txt = e.get("text") or e.get("title")
            txt = txt.strip() if isinstance(txt, str) else None

            # build text mask 
            if txt is None or txt == "*":
                # universal wild card > all texts for a file
                mask = mask_file
            elif "*" in txt:
                # prefix wildcard: 
                prefix = txt.replace("*","").rstrip()
                mask = mask_file & df["Text Title"].str.startswith(prefix)
            else:
                # exact title 
                mask = mask_file & (df["Text Title"] == txt)

            # assign the corresponding fields
            for field in yaml_cols:
                if field in e:
                    val = e[field]
                    if isinstance(val, list):
                        val = ", ".join(val)
                    df.loc[mask, field] = val

    return df

# function call 
yaml_cols = ["century","exact","lang","source","place"]
df_enriched = enrich_with_wildcard(df, YAML_FILE, yaml_cols)

cols = [c for c in yaml_cols if c in df_enriched.columns]


########################
# test: 'nov-marg' files 
########################
inputfile = "nov-marg"
print(
    df_enriched.loc[
        df_enriched["File"] == inputfile,
        # ["Text Title", "century", "exact", "lang", "source", "place"]
        ["Text Title"] + yaml_cols
    ]
    .drop_duplicates()
    .head()
)
# Out:
#                   Text Title century exact lang source     place
# 289148  September, folio 176      13  None   OR   None  Novgorod
# 289179    October, folio 127      13  None   OR   None  Novgorod
# 289192   September, folio 56      13  None   OR   None  Novgorod
# 289209   September, folio 57      13  None   OR   None  Novgorod
# 289214   September, folio 84      13  None   OR   None  Novgorod

# %% [markdown]
# ## Data Validation
# - missing "place" values in "File" or "Text Title"?
# - missing info about "century" in "File"?

# %%
# missing information for "place" in "File" or "Text Title"? 
# filter place == NaN 
missing_place = df_enriched.loc[df_enriched['place'].isna(), ['File', 'Text Title']]
assert len(missing_place) == 0, "Information for 'place' missing"

# %%
# missing information for "century" in "File"?
# list of 'File'-cols where 'century' is None/NaN:
files_missing_century = df_enriched.loc[df_enriched['century'].isna(), 'File'].unique().tolist()
assert len(files_missing_century) == 0, "Information for 'century' missing"

# %%
# print first two rows of a random file to make sure data look as expected
df_enriched[df_enriched["File"]=="birchbark"].head(2)
# Out:
#             File Text Title Language  Sentence ID  Token ID     Form    Lemma  \
# 79818  birchbark          9      orv       210135   2287444        ѿ      отъ
# 79819  birchbark          9      orv       210135   2287445  гостѧтꙑ  гостята
#
#       POS  Morphology  Head ID Relation Presentation After  \
# 79818  R-  ---------n  2287814      obl
# 79819  Ne  -s---fg--i  2287444      obl
#
#       Russian Translation English Translation Type century      exact  \
# 79818        от, из, с, у            from, of   OR      12  1160‒1180
# 79819                <NA>                <NA>   OR      12  1160‒1180
#
#             lang source     place
# 79818  birchbark   None  Novgorod
# 79819  birchbark   None  Novgorod

# %% [markdown]
# ### Column "century"
# - Show all unique values in column "century"
# - Clean "century" column by stripping fractional century information (e.g. "16/2" → "16")
# - Convert normalized "century" values to Int64 dtype

# %%
# all centuries in column "century"?
which_centuries = df_enriched["century"].unique()
print(which_centuries)
# Out:
# [12 '12' '14' '11' '13' '15' 15 '15/2' '17/2' '17' '16/2' 16 11 13]

# %%
df_enriched["century"] = (
    df_enriched["century"]
    .astype(str) # cast to string 
    .str.split("/") # delim 
    .str[0] # cut off second element -> only whole centuries are kept (16/2-> 16)
    .replace("None", pd.NA) # cast "None" to "N.A." -> N.A. compatible with Int64 (≠ None)
    .astype("Int64") # allows N.A. values (≠ int)
)

# %% [markdown]
# Verify century type casting

# %%
filtered_df = df_enriched[df_enriched["File"] == "dux-grjaz"]
display(filtered_df.head(2))
# Out:
#              File                            Text Title Language  Sentence ID  \
# 235438  dux-grjaz  Testament of Ivan Jurievich Grjaznoj      orv       213401
# 235439  dux-grjaz  Testament of Ivan Jurievich Grjaznoj      orv       213401
#
#         Token ID Form Lemma POS  Morphology  Head ID Relation  \
# 235438   2306029  ﻿Во    въ  R-  ---------n  2306047      adv
# 235439   2306030  имѧ   имя  Nb  -s---na--i  2306029      obl
#
#        Presentation After Russian Translation    English Translation Type  \
# 235438                              в, на, за  in, into, on, at, for   OR
# 235439                                    имя                   name   OR
#
#         century exact lang source   place
# 235438       16  1579   OR   None  Moscow
# 235439       16  1579   OR   None  Moscow

# %%
which_centuries = df_enriched["century"].sort_values().unique()
print(which_centuries)
# Out:
# <IntegerArray>
# [11, 12, 13, 14, 15, 16, 17]
# Length: 7, dtype: Int64

# %% [markdown]
# ## Corpus Statistics:
# - tokens per century
# - verb tokens per century

# %%
# evaluation: how many tokens (all parts of speech) per "century"
df_enriched.century.value_counts().sort_index()
# Out:
# century
# 11    25932
# 12    93208
# 13    20447
# 14     3095
# 15    42789
# 16    23880
# 17    25924
# Name: count, dtype: Int64

# %%
# how many verb lemmas per century are in the DF?
df_enriched.loc[df_enriched["POS"] == "V-", "century"].value_counts().sort_index()
# Out:
# century
# 11     5145
# 12    17994
# 13     3115
# 14      455
# 15     7414
# 16     3623
# 17     4906
# Name: count, dtype: Int64

# %% [markdown]
# ## Data Validation:
# ### Data Validation: Value "lang"
# All columns contain value for "lang" (=language)?

# %%
filtered_df_lang_none = df_enriched[df_enriched["lang"].isna()]
unique_files = filtered_df_lang_none["File"].unique()
print(unique_files)
nunique_files = filtered_df_lang_none["File"].nunique()
print(nunique_files)

# If amount of unique files missing entry "lang" is not NULL -> return Error 
assert len(filtered_df_lang_none) == 0, "Error: missing entries for column 'lang'"
# Out:
# []
# 0

# %% [markdown]
# ### Data Validation: Column "exact"
# Convert the "exact" column to a single year (YYYY), representing the beginning of the manuscript's creation.

# %%
df_enriched["exact"].value_counts().head()
# Out:
# exact
# 1377         56725
# 1672-1675    22835
# 1417         20361
#               8830
# 1490          2487
# Name: count, dtype: int64

# %%
df_enriched["exact"] = (
    pd.to_numeric(
        # 1. ensure string dtype for consistent string operations
        df_enriched["exact"].astype("string")
        # 2. extract first 4 characters (target: YYYY)
        .str.slice(0, 4)
        # 3. remove leading/trailing whitespace
        .str.strip(),
        # 4. coerce invalid / non-numeric values to NaN
        errors="coerce"
    )
    # 5. cast to pandas nullable integer type (allows NaN)
    .astype("Int64")
    # 6. replace missing values (NaN) with sentinel value (-1)
    .fillna(-1)
)

# %%
# Show the amount of tokens for each corresponding year in column "exact"
# (-1 if value for "exact" is missing)
df_enriched["exact"].value_counts().head(10)
# Out:
# exact
# -1      125172
# 1377     56725
# 1672     22835
# 1417     20361
# 1490      2487
# 1663      1835
# 1229      1421
# 1266       423
# 1579       421
# 1100       386
# Name: count, dtype: Int64

# %% [markdown]
# ## Write data to csv

# %%
OUTPUT_PATH = os.path.join(OUTPUT_DIR, "dataframe_02_1.csv")
df_enriched.to_csv(OUTPUT_PATH, index=False)
